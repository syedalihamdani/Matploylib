# %%
from numpy import *

# %%
from pylab import *

# %%
x=linspace(-3,3,30)

# %%
y=x**2

# %%
plot(x,y)
show()

# %% [markdown]
# #### Instead of drawing the line, We can draw the symbol with the help of symbol and color

# %% [markdown]
# #### Symbols  -, _,-.,,.,,,o,^,v,<,>,,s,+,x,D,d,1,2,3,4,h,H,p,|,_

# %% [markdown]
# #### Colors b,g,r,,c,m,y,k,w

# %%
x=linspace(-3,3,30)

# %%
y=x**2

# %%
plot(x,y,'k-')
show()

# %%
clf()  # To clean the plot

# %%
plot(x,sin(x))
plot(x,cos(x),'r-')
plot(x,-sin(x),'g--')
show()
